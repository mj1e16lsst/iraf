# %%
from pyraf import iraf
from iraf import artdata
import subprocess
import os
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.visualization import SqrtStretch
from matplotlib.colors import LogNorm

# %%
os.chdir('/home/mj1e16/iraf/')

# %%
imageName = ('/home/mj1e16/testImages/diff_imNo0_channel1.fits')

# %%
def MKObjects(imageName,outName,objects='starfield.dat',gain=110,rdnoise=127,ar=1,pa=0):
    artdata.mkobjects(imageName,output=outName,objects='starfield.dat',gain=gain,rdnoise=rdnoise,ar=ar,pa=pa)
    hdu = fits.open(outName)
    im1 = hdu[0].data
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.imshow(im1,cmap='Greys',norm=LogNorm(),vmin=1,vmax=500)
    plt.show()

# %%
outName = 'test.fits'

# %%
normalise = ImageNormalize(stretch=SqrtStretch())

# %%
artdata.mkobjects(imageName,output=outName,objects='starfield.dat',gain=110,rdnoise=127)

# %%
hdu = fits.open(outName)
im1 = hdu[0].data
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(im1,cmap='Greys',norm=LogNorm(),vmin=1,vmax=500)
plt.show()

# %%
MKObjects(imageName,'test5.fits',ar='1.',pa='45.')

# %%
MKObjects(imageName,'testsdf1.fits',ar=str(6/10.),pa='135.')
